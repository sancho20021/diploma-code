# %%
from datetime import timedelta, datetime
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import math

# %%
data = pd.read_json('../kalman_experiments/logs/data.json', lines=True)

def plot(data, figsize=(8, 6)):
    fig, ax = plt.subplots(figsize=figsize)

    times = data['t']
    try:
        ax.plot(times, data['v'], label='input intensity')
        ax.plot(times, data['d'], label='accumulated_demand')
        ax.plot(times, data['l_actual'], label='actual capacity')
        ax.plot(times, data['l_estimated'], label='estimated capacity')
    except:
        pass

    ax.legend()
    ax.set_xlabel('iterations')
    plt.show()

plot(data)

# %%
data = pd.read_json('../kalman_experiments/logs/kalman_control.json', lines=True)
plot(data)

# fig, ax = plt.subplots(figsize=(17, 10))

# times = data['t']
# ax.plot(times, data['v'], label='input intensity')
# ax.plot(times, data['d'], label='accumulated_demand')
# ax.plot(times, data['l_actual'], label='actual capacity')
# ax.plot(times, data['l_estimated'], label='estimated capacity')

# ax.legend()
# ax.set_xlabel('iterations')
# plt.show()

# %%
data = pd.read_json('../kalman_experiments/logs/p_control_-1.json', lines=True)
plot(data)

# fig, ax = plt.subplots(figsize=(17, 10))

# times = data['t']
# ax.plot(times, data['v'], label='input intensity')
# ax.plot(times, data['d'], label='accumulated_demand')
# ax.plot(times, data['l_actual'], label='actual capacity')

# ax.legend()
# ax.set_xlabel('iterations')
# plt.show()

# %%
plot(pd.read_json('../kalman_experiments/logs/p_control_-0.5.json', lines=True))

# fig, ax = plt.subplots(figsize=(17, 10))

# times = data['t']
# ax.plot(times, data['v'], label='input intensity')
# ax.plot(times, data['d'], label='accumulated_demand')
# ax.plot(times, data['l_actual'], label='actual capacity')

# ax.legend()
# ax.set_xlabel('iterations')
# plt.show()

# %%
plot(pd.read_json('../kalman_experiments/logs/p_control_-2.json', lines=True))

# fig, ax = plt.subplots(figsize=(17, 10))

# times = data['t']
# ax.plot(times, data['v'], label='input intensity')
# ax.plot(times, data['d'], label='accumulated_demand')
# ax.plot(times, data['l_actual'], label='actual capacity')

# ax.legend()
# ax.set_xlabel('iterations')
# plt.show()

# %%
plot(pd.read_json('../kalman_experiments/logs/p_control_-2.01.json', lines=True))

# fig, ax = plt.subplots(figsize=(17, 10))

# times = data['t']
# ax.plot(times, data['v'], label='input intensity')
# ax.plot(times, data['d'], label='accumulated_demand')
# ax.plot(times, data['l_actual'], label='actual capacity')

# ax.legend()
# ax.set_xlabel('iterations')
# plt.show()

# %%
plot(pd.read_json('../kalman_experiments/logs/analytical_control.json', lines=True))

# fig, ax = plt.subplots(figsize=(17, 10))

# times = data['t']
# ax.plot(times, data['v'], label='input intensity')
# ax.plot(times, data['d'], label='accumulated_demand')
# ax.plot(times, data['l_actual'], label='actual capacity')

# ax.legend()
# ax.set_xlabel('iterations')
# plt.show()

# %%
plot(pd.read_json('../kalman_experiments/logs/kalman_normal_no_control.json', lines=True))

# %%
plot(pd.read_json('../kalman_experiments/logs/analytical_control_normal.json', lines=True))

# %%
plot(data = pd.read_json('../kalman_experiments/logs/kalman_control_normal.json', lines=True))

# %%
plot(data = pd.read_json('../kalman_experiments/logs/kalman_control_normal_underutil.json', lines=True))

# %%
plot(data = pd.read_json('../kalman_experiments/logs/kalman_control_normal_limit.json', lines=True))
